# %%
import pandas as pd
import matplotlib.pyplot as plt

path = ''

# %%
filename = 'data/output_populations_3-1000.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
filename = 'data/output_populations_3-1000-0.0001.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
filename = 'data/output_populations_3-1000-0.00005.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
filename = 'data/output_populations_4-2000.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
filename = 'data/output_populations_5-1000-0.0001-true.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
filename = 'data/output_populations_5-3000.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
filename = 'data/output_populations_10-5000.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#2 species (1) Inmigration = 0.001, Reproduction_Rate = 0.1
filename = 'data/output_populations_2-1000-l-l.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#2 species (2) Inmigration = 0.001, Reproduction_Rate = 0.01
filename = 'data/output_populations_2-1000-l-s.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#2 species (3) Inmigration = 0.00001, Reproduction_Rate = 0.1
filename = 'data/output_populations_2-1000-s-l.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#2 species (4) Inmigration = 0.00001, Reproduction_Rate = 0.01
filename = 'data/output_populations_2-1000-s-s.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#3 species Inmigration = 0.0001, Reproduction_Rate = 0.1
# 3 -> 1 -> 2
filename = 'data/output_populations_3-1000-h-l.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#3 species Inmigration = 0.001, Reproduction_Rate = 0.1
# 1 -> 2
# 3 -> 2
filename = 'data/output_populations_3-1000-d-l.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#3 species Inmigration = 0.01, Reproduction_Rate = 0.1
# 3 -> 1 -> 2
filename = 'data/output_populations_3-1000-0.01-l.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#3 species Inmigration = 0.1, Reproduction_Rate = 0.1
# 1 -> 3
# 2 -> 3
filename = 'data/output_populations_3-1000-0.1-l.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()

# %%
#3 species Inmigration = 0.0001, Reproduction_Rate = 0.1
# 1 -> 2 
# 1 -> 3
# 2 -> 3
filename = 'data/output_populations_3-500-h-l.csv'
file = path+filename
df = (pd.read_csv(file, sep=",", header=0))
df = df.drop(columns=['iteration'])
df.plot()
