# %%
import pyEDM
import matplotlib.pyplot as plt

# %%
sardine_anchovy_sst = pyEDM.sampleData['sardine_anchovy_sst']
print(sardine_anchovy_sst.head(10))
# Out:
# year   anchovy   sardine   sio_sst    np_sst
# 0  1929 -0.007599  1.770090 -0.352393 -0.347846
# 1  1930 -0.009602 -1.151520  0.001149  0.328734
# 2  1931 -0.008444 -1.420680  1.068220  1.610270
# 3  1932 -0.008354  0.112222  0.531857  1.265340
# 4  1933 -0.007750  1.515550 -0.552058  0.040046
# 5  1934 -0.009531  2.989870 -1.143300 -0.691345
# 6  1935 -0.009964 -0.526375 -0.899012 -0.586502
# 7  1936 -0.007800  0.977476  0.287626  0.665017
# 8  1937 -0.007458 -0.451011 -0.002360  0.421038
# 9  1938  0.003472  0.362572 -0.022109  0.551965

# %%
sardine_anchovy_sst[['anchovy','np_sst']].plot()

# %%
pyEDM.CCM(dataFrame=sardine_anchovy_sst, E=3, columns="anchovy", target="np_sst", libSizes="10 70 10", showPlot=True, sample=100)
# Out:
#    LibSize  anchovy:np_sst  np_sst:anchovy
# 0     10.0       -0.056683       -0.292218
# 1     20.0        0.024232       -0.137438
# 2     30.0        0.097286       -0.102464
# 3     40.0        0.124840       -0.088216
# 4     50.0        0.162498       -0.067725
# 5     60.0        0.187365       -0.052975
# 6     70.0        0.186488       -0.086479
